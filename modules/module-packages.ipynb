# %%
import numpy as np
import math

# %%
from math import *
print(sqrt(16))
# Out:
# 4.0

# %%
from package.math import add
add(2,5)
# Out:
# 7

# %%
from package.subpackage.mul import multiply
multiply(2,5)
# Out:
# 10
