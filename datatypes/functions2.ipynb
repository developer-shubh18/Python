# %% [markdown]
# # Function Examples

# %% [markdown]
# ## Example 1 : Temperature conversion

# %%
def convert_temp(temp, unit):
    """ THis function converts temp b/w cel and farenheit"""""
    if unit=='C':
        return temp *9/5+32 ##cel to fahren
    elif unit =='F':
        return (temp-32)*5/9 ## F to C
    else:
        return None

print(convert_temp(25,'C'))
print(convert_temp(77,'F'))
# Out:
# 77.0
# 25.0

# %% [markdown]
# ### Example 2: Password Strength Checker
