# %%
import os
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory {new_directory} is created.")
# Out:
# Directory package is created.

# %%
items = os.listdir(".")
print(items)
# Out:
# ['fileoperation.ipynb', 'destination.txt', 'filepath.ipynb', 'example.bin', 'example.txt', 'package']

# %%
# joining paths 
directory_name = "folder"
file_name = "file.txt"
full_path = os.path.join(directory_name, file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
import os
full_path = os.path.join(os.getcwd(), directory_name, file_name)
print(full_path)
# Out:
# /Users/shubh/Desktop/Programs/Python/File and Exception handling/folder/file.txt

# %%
# Check if paths exists
example_file = "example1.txt"
if os.path.exists(example_file):
    print(f"The path {example_file} exists.")
else:
    print(f"The path {example_file} does not exist.")
# Out:
# The path example1.txt does not exist.

# %%
# Check. if a path is file or a directory
path = "example.txt"
if os.path.isfile(path):
    print(f"The path {path} is a file.")
elif os.path.isdir(path):
    print(f"The path {path} is a directory.")
else:
    print(f"The path {path} is neither a file nor a directory.")
# Out:
# The path example.txt is a file.

# %%
# Relative and absolute path
relative_path = "example.txt"
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /Users/shubh/Desktop/Programs/Python/File and Exception handling/example.txt
